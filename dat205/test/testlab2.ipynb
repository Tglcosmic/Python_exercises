# %%
import pandas as pd

# %%
#đọc thử file excel
filepath = r'H:\Python_exercises\dat205\data\Vietnam_ZipCode.xlsx'
#có thể truyền tham số để lấy sheet mà mình muốn 
#nếu ko truyền vào index thì mặc định sẽ lấy sheet đầu tiên
df_excel = pd.read_excel(filepath, sheet_name=2)
#df_csv = pd.read_excel(filepath, sheet_name=['HN','HCM']) #cách 2
df_excel

# %%
#đọc file CSV
file_path = r"H:\Python_exercises\dat205\data\02-1.employee_data.csv"
df_csv = pd.read_csv(file_path)
df_csv
# Out:
#         ID     Name     Sex  Age Department  Salary
# 0   PS5240    David    Male   44  Marketing    6300
# 1   PS2201      Bob    Male   45    Finance    8300
# 2   PS5269      Eva  Female   29         IT    5900
# 3   PS7347   Sophia    Male   26         HR    4100
# 4   PS3171      Bob  Female   33      Sales    6900
# ..     ...      ...     ...  ...        ...     ...
# 95  PS3650   Olivia     NaN   38  Marketing    5400
# 96  PS1476      Eva  Female   41         IT    8800
# 97  PS1631  Charlie    Male   41    Finance    9400
# 98  PS3793      Eva    Male   30      Sales    8700
# 99  PS9894  Charlie     NaN   33      Sales    9100
#
# [100 rows x 6 columns]

# %%
#lấy 5 dòng đầu tiên 
df_csv.head()

# %%
df_csv.info()

# %%
df_csv.sample(2)

# %%
#lấy 5 dòng cuối cùng 
df_csv.tail()

# %%
df_csv.shape

# %%
df_csv.info(show_counts=True)

# %%
df_csv.describe()

# %%
df_csv.describe(include='all')

# %%
s =df_csv['Age']
s
type(s)

# %%
df_csv['Department'].describe()

# %%
#đếm có bao nhiêu giá trị khác nhau
df_csv['Department'].nunique()

# %%
df_csv.columns

# %%
df_csv[df_csv['Age']>25]
# Out:
#         ID     Name     Sex  Age Department  Salary
# 0   PS5240    David    Male   44  Marketing    6300
# 1   PS2201      Bob    Male   45    Finance    8300
# 2   PS5269      Eva  Female   29         IT    5900
# 3   PS7347   Sophia    Male   26         HR    4100
# 4   PS3171      Bob  Female   33      Sales    6900
# ..     ...      ...     ...  ...        ...     ...
# 95  PS3650   Olivia     NaN   38  Marketing    5400
# 96  PS1476      Eva  Female   41         IT    8800
# 97  PS1631  Charlie    Male   41    Finance    9400
# 98  PS3793      Eva    Male   30      Sales    8700
# 99  PS9894  Charlie     NaN   33      Sales    9100
#
# [96 rows x 6 columns]

# %%
df_csv[df_csv['Sex']=='Male']
# Out:
#         ID      Name   Sex  Age Department  Salary
# 0   PS5240     David  Male   44  Marketing    6300
# 1   PS2201       Bob  Male   45    Finance    8300
# 3   PS7347    Sophia  Male   26         HR    4100
# 5   PS9818       Bob  Male   36         IT    7800
# 8   PS9255  Tony Teo  Male   27    Finance    5200
# 10  PS2106   Charlie  Male   40  Marketing    9000
# 11  PS6517     David  Male   45         IT    7400
# 12  PS2124  Tony Teo  Male   29  Marketing    6800
# 13  PS3166    Olivia  Male   34    Finance    6500
# 14  PS5829  Tony Teo  Male   41    Finance    4400
# 33  PS7197   Charlie  Male   33    Finance    9200
# 37  PS5975   William  Male   44  Marketing    6400
# 38  PS9358       Bob  Male   28      Sales    4400
# 39  PS1317    Sophia  Male   40      Sales    5000
# 46  PS7645     Alice  Male   44         HR    4800
# 47  PS6263       Bob  Male   33    Finance    4000
# 48  PS8221    Sophia  Male   40         IT    8300
# ...

# %%
df_csv.loc[df_csv['Age'] == '45', 'Sex']
# Out:
# Series([], Name: Sex, dtype: object)
